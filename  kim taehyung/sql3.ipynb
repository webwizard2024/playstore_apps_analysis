# %%
import sqlite3
import pandas as pd

# %%
! pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.0 MB 9.1 MB/s eta 0:00:02
#    ------------- -------------------------- 3.7/11.0 MB 9.9 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/11.0 MB 9.6 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.0 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 9.1 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
# ...

# %%
file_path ="Financial_Sample_Extended.xlsx"
df = pd.read_excel(file_path)

# %%
print(df)
# Out:
#                Segment                   Country   Product Discount_Band  \
# 0     Channel Partners                    Canada  Amarilla          High
# 1     Channel Partners                    Canada  Amarilla          High
# 2     Channel Partners                    Canada  Amarilla          High
# 3     Channel Partners                    Canada  Amarilla          High
# 4     Channel Partners                    Canada  Amarilla          High
# ...                ...                       ...       ...           ...
# 6995    Small Business  United States of America      Velo        Medium
# 6996    Small Business  United States of America      Velo        Medium
# 6997    Small Business  United States of America      Velo        Medium
# 6998    Small Business  United States of America      Velo        Medium
# 6999    Small Business  United States of America      Velo        Medium
#
#       Units_Sold  Manufacturing_Price  Sale_Price  Gross_Sales  Discounts  \
# ...

# %%
conn = sqlite3.connect("financial_data.db")
cursor = conn.cursor()

# Step 3: Create table (auto-generate from DataFrame columns)
table_name = "financial_sample"

# Drop table if exists (optional)
cursor.execute(f"DROP TABLE IF EXISTS {table_name}")

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount_Band', 'Units_Sold',
#        'Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month_Number', 'Month_Name', 'Year',
#        'Discount_Rate', 'Sales_Base_Case', 'Sales_Optimistic',
#        'Sales_Pessimistic', 'Profit_Base_Case', 'Profit_Optimistic',
#        'Profit_Pessimistic', 'Sales_Growth_Rate', 'Profit_Growth_Rate'],
#       dtype='object')

# %%
columns=",".join([f'"{col}" TEXT' for col in df.columns])

# %%
columns
# Out:
# '"Segment" TEXT,"Country" TEXT,"Product" TEXT,"Discount_Band" TEXT,"Units_Sold" TEXT,"Manufacturing_Price" TEXT,"Sale_Price" TEXT,"Gross_Sales" TEXT,"Discounts" TEXT,"Sales" TEXT,"COGS" TEXT,"Profit" TEXT,"Date" TEXT,"Month_Number" TEXT,"Month_Name" TEXT,"Year" TEXT,"Discount_Rate" TEXT,"Sales_Base_Case" TEXT,"Sales_Optimistic" TEXT,"Sales_Pessimistic" TEXT,"Profit_Base_Case" TEXT,"Profit_Optimistic" TEXT,"Profit_Pessimistic" TEXT,"Sales_Growth_Rate" TEXT,"Profit_Growth_Rate" TEXT'

# %%
create_table_query = f"CREATE TABLE {table_name} ({columns});"

# %%
create_table_query
# Out:
# 'CREATE TABLE financial_sample ("Segment" TEXT,"Country" TEXT,"Product" TEXT,"Discount_Band" TEXT,"Units_Sold" TEXT,"Manufacturing_Price" TEXT,"Sale_Price" TEXT,"Gross_Sales" TEXT,"Discounts" TEXT,"Sales" TEXT,"COGS" TEXT,"Profit" TEXT,"Date" TEXT,"Month_Number" TEXT,"Month_Name" TEXT,"Year" TEXT,"Discount_Rate" TEXT,"Sales_Base_Case" TEXT,"Sales_Optimistic" TEXT,"Sales_Pessimistic" TEXT,"Profit_Base_Case" TEXT,"Profit_Optimistic" TEXT,"Profit_Pessimistic" TEXT,"Sales_Growth_Rate" TEXT,"Profit_Growth_Rate" TEXT);'

# %%
cursor.execute(create_table_query)

# %%
df.to_sql(table_name, conn, if_exists="append", index=False)
# Out:
# 7000

# %%
conn.commit()

# %%
import pandas as pd 
import psycopg2
from sqlalchemy  import create_engine,text 
file_path ="Financial_Sample_Extended.xlsx"
df = pd.read_excel(file_path)


# PostgreSQL credentials
username = "postgres"
password = "postgres"
host = "localhost"
port = "5432"
data_base ="user_12345"

conn = psycopg2.connect(
    dbname="postgres",
    user=username,
    password=password,
    host=host,
    port=port
)

conn.autocommit = True
cur = conn.cursor()

cur.execute(f"SELECT 1 FROM pg_database WHERE datname = '{data_base}'")

exists = cur.fetchone()
if not exists:
    cur.execute(f'CREATE DATABASE "{data_base}"')
    print(f"✅ Database '{data_base}' created.")
else:
    print(f"ℹ️ Database '{data_base}' already exists.")

cur.close()
conn.close()
# Out:
# ✅ Database 'user_12345' created.

# %%
# Step 3: Load Excel file
file_path = "Financial_Sample_Extended.xlsx"
df = pd.read_excel(file_path)

# Step 4: Connect to target database using SQLAlchemy
engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{data_base}")
conn = engine.connect()

table_name = "financial_sample"

# Drop table if exists (optional)
conn.execute(text(f'DROP TABLE IF EXISTS "{table_name}"'))

# Step 5: Insert DataFrame into PostgreSQL
df.to_sql(table_name, engine, if_exists="replace", index=False)

# Close connection
conn.close()
print("✅ Data inserted into PostgreSQL successfully!")
# Out:
# ✅ Data inserted into PostgreSQL successfully!
